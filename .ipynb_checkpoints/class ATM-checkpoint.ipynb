# %% [markdown]
# Data
# - Balance
# - ATM pin
#
# Behaviors
# - Create pin
# - Deposit
# - Withdraw
# - Check balanace

# %%
class Atm:
    
    def __init__(self):
        self.balance = 0
        self.atm_pin = ""
        
    def menu(self):
        options = [
            "Create PIN",
            "Deposit",
            "Withdraw",
            "Check Balance"
        ]

        print("=" * 40)
        print("💳 Welcome to ATM Service".center(40))
        print("=" * 40)
        print("Please choose an option:\n")

        for idx, option in enumerate(options, start=1):
            print(f" {idx}. 🟢 {option}")

        print("\n" + "-" * 40)
        user_input = input("👉 Enter your choice (1-4): ")
        print("-" * 40)
        print(f"✅ You selected option {user_input}")
