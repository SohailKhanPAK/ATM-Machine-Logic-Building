# %% [markdown]
# Data
# - Balance
# - ATM pin
#
# Behaviors
# - Create pin
# - Deposit
# - Withdraw
# - Check balanace

# %%
class Atm:
    
    def __init__(self):
        self.balance = 0
        self.atm_pin = ""
    
    def menu(self):
        pass
